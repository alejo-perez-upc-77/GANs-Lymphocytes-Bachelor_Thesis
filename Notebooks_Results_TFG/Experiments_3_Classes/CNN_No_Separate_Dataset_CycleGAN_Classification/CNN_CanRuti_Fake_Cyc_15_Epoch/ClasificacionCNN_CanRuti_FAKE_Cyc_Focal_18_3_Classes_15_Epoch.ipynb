# %% [markdown]
# # Cargamos Datos

# %%
import fastai
import torch
from fastai.vision import *
from shutil import copyfile
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

# %%
path = '/shared/pytorch-CycleGAN-and-pix2pix/results_TFG/CanRuti_Clinic_NoNormal/CanRuti_Clinic_NoNormal/test_15/images'

# %%
variant = os.listdir('/shared/Datasets_Classification/Classification_CanRuti/VARIANT_LYMPHOCYTE')
atypical = os.listdir('/shared/Datasets_Classification/Classification_CanRuti/ATYPICAL_LYMPHOCYTE')
blast = os.listdir('/shared/Datasets_Classification/Classification_CanRuti/BLAST')

# %%
def catcher(x): return re.findall('([a-zA-Z]+_+[\d]+)', x)[0]

# %%
variant_png = [catcher(i)+'_fake_B.png' for i in variant]
atypical_png = [catcher(i)+'_fake_B.png' for i in atypical]
blast_png = [catcher(i)+'_fake_B.png' for i in blast]

# %%
#for i in variant_png:
#    copyfile(os.path.join(path,i), os.path.join("/shared/Datasets_Classification/CanRuti_Fake_Cyc_Epoch_15/VARIANT_LYMPHOCYTE", i))
#    
#for i in blast_png:
#    copyfile(os.path.join(path,i), os.path.join("/shared/Datasets_Classification/CanRuti_Fake_Cyc_Epoch_15/BLAST", i))
#    
#for i in atypical_png:
#    copyfile(os.path.join(path,i), os.path.join("/shared/Datasets_Classification/CanRuti_Fake_Cyc_Epoch_15/ATYPICAL_LYMPHOCYTE", i))
#

# %%
folder_1 = os.listdir("/shared/Datasets_Classification/CanRuti_Fake_Cyc/ATYPICAL_LYMPHOCYTE")
folder_2 = os.listdir("/shared/Datasets_Classification/CanRuti_Fake_Cyc/VARIANT_LYMPHOCYTE")
folder_3 = os.listdir("/shared/Datasets_Classification/CanRuti_Fake_Cyc/BLAST")
dic_Classif = {
      'ATYPICAL_LYMPHOCYTE':len(folder_1),
      'VARIANT_LYMPHOCYTE':len(folder_2),
      'BLAST':len(folder_3)
     }

pd.DataFrame(dic_Classif, index=['N'])
# Out:
#    ATYPICAL_LYMPHOCYTE  VARIANT_LYMPHOCYTE  BLAST
# N                   47                  57     80

# %%
folder_classes = "/shared/Datasets_Classification/CanRuti_Fake_Cyc_Epoch_15"
tfms = get_transforms(flip_vert=True, max_warp=None, max_zoom=1.01, max_rotate=120, max_lighting=0.1)

# %% [markdown]
# #### Creación del DataBunch de las imágenes de Can Ruti Fake

# %% [markdown]
# Aunque haya una separación del 50 por ciento en cada set, solo se utilizará un conjunto de validación para el test, el de training se ignorará

# %%
df_train = pd.read_csv('/shared/can_ruti/train.csv')
df_train['x'] = df_train['x'].apply(lambda x: x.replace('.jpg', '_fake_B.png'))
df_train['z'] = False
df_train.head()
# Out:
#                               x      y      z
# 0  BLAST/BL_10600573_fake_B.png  BLAST  False
# 1  BLAST/BL_13076127_fake_B.png  BLAST  False
# 2  BLAST/BL_12630836_fake_B.png  BLAST  False
# 3  BLAST/BL_10600634_fake_B.png  BLAST  False
# 4  BLAST/BL_12630955_fake_B.png  BLAST  False

# %%
df_valid = pd.read_csv('/shared/can_ruti/validation.csv')
df_valid['x'] = df_valid['x'].apply(lambda x: x.replace('.jpg', '_fake_B.png'))
df_valid['z'] = True
df_valid.head()
# Out:
#                                             x                    y     z
# 0  ATYPICAL_LYMPHOCYTE/LY_13166703_fake_B.png  ATYPICAL_LYMPHOCYTE  True
# 1  ATYPICAL_LYMPHOCYTE/LY_13103960_fake_B.png  ATYPICAL_LYMPHOCYTE  True
# 2                BLAST/BL_10600656_fake_B.png                BLAST  True
# 3   VARIANT_LYMPHOCYTE/LY_13130834_fake_B.png   VARIANT_LYMPHOCYTE  True
# 4                BLAST/BL_10600719_fake_B.png                BLAST  True

# %%
df_split = pd.concat([df_train, df_valid])
df_split = df_split.rename(columns={'x': 'name','y': 'label','z':'is_valid'})
df_split.head()
# Out:
#                            name  label  is_valid
# 0  BLAST/BL_10600573_fake_B.png  BLAST     False
# 1  BLAST/BL_13076127_fake_B.png  BLAST     False
# 2  BLAST/BL_12630836_fake_B.png  BLAST     False
# 3  BLAST/BL_10600634_fake_B.png  BLAST     False
# 4  BLAST/BL_12630955_fake_B.png  BLAST     False

# %%
folder_classes
# Out:
# '/shared/Datasets_Classification/CanRuti_Fake_Cyc_Epoch_15'

# %%
data = (ImageList.from_df(df_split, folder_classes) #Where to find the data? -> in path and its subfolders
        .split_from_df()         #How to split in train/valid? -> use the folders
        .label_from_folder()            #How to label? -> depending on the folder of the filenames
        .transform(tfms, size=224)       #Data augmentation? -> use tfms with a size of 64
        .databunch(num_workers=0)
        .normalize(imagenet_stats))

# %%
data.batch_size = 20

# %% [markdown]
# #### Descripción del Conjunto de datos Can Ruti Fake

# %%
pd.DataFrame.from_dict({'Number of classes':[data.c],
'train_size':[len(data.train_ds)],
'valid_size':[len(data.valid_ds)]},
orient = 'index', columns=['N'])
# Out:
#                     N
# Number of classes   3
# train_size         92
# valid_size         92

# %% [markdown]
# #### Conteo de clases del conjunto de training de datos Can Ruti Fake

# %% [markdown]
# train_ds = data.train_ds.to_df()
# pd.DataFrame(train_ds['y'].value_counts()).rename(columns={'y':'N'})

# %% [markdown]
# #### Conteo de clases del conjunto de validación de datos Can Ruti Fake

# %% [markdown]
# valid_ds = data.valid_ds.to_df()
# pd.DataFrame(valid_ds['y'].value_counts()).rename(columns={'y':'N'})

# %%
data.show_batch()

# %% [markdown]
# # Test Canruti Resnet 18 Focal Loss Preentrenada en Clinic - Dataset Can Ruti Fake CycleGAN 15 Epochs No separate

# %% [markdown]
# Se crea un learner con datos auxilares del clinic pero se sustituye con el Databunch de CanRuti anterior para validar en CanRuti. Nótese que se incorporan los pesos del clínic con el método `.load()`

# %%
folder_models = "/shared/Datasets_Classification/Classification_Clinic_Balanced"
learn = None
learn = load_learner(folder_models, 'export_stage-2-18-Clinic_Focal_3_Classes')
learn.data = data

# %% [markdown]
# Estadísticas de la validación den CanRuti

# %%
results = learn.validate(data.valid_dl)

valid_CanRuti = dict(zip(['valid_loss', 'error_rate', 'accuracy'],
                         [results[0], results[1].item(),results[2].item()]) )

pd.DataFrame(valid_CanRuti, index = ['metrics'])
# Out:
#          valid_loss  error_rate  accuracy
# metrics    1.098231    0.315217  0.684783

# %%
plt.rcParams.update({'font.size': 18})

from sklearn.metrics import roc_auc_score
from sklearn import preprocessing
from sklearn.metrics import precision_score, recall_score

def multiclass_roc_auc_score(y_test, y_pred, average="micro"):
    lb = preprocessing.LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)
    return roc_auc_score(y_test, y_pred, average=average)

val_preds,val_targets = learn.get_preds() 

y_test = pd.Series(np.array(val_preds.max(1)[1])).map(dict(zip([0,1,2],learn.data.classes)))
y_true = pd.Series(np.array(val_targets)).map(dict(zip([0,1,2],learn.data.classes)))


precision = precision_score(y_test, y_true, average='micro')
recall = recall_score(y_test, y_true, average='micro')

pd.DataFrame({'multiclass_roc_auc_score': multiclass_roc_auc_score(y_test, y_true),
             'precision':precision,
             'recall':recall,
             }, index = ['metrics'])
# Out:
#          multiclass_roc_auc_score  precision    recall
# metrics                  0.763587   0.684783  0.684783

# %% [markdown]
# `Matriz de confusión` de la validación en Can Ruti

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
interp.plot_confusion_matrix(figsize=(7,7), dpi=110)

# %% [markdown]
# `Matriz de confusión normalizada` de la validación en Can Ruti

# %%
interp.plot_confusion_matrix(figsize=(7,7), dpi=110, normalize=True)

# %%
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# #### Fine Tuning en el conjunto de CanRuti

# %%
learn.unfreeze()
learn.fit_one_cycle(4, max_lr=3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.824506</td>
#       <td>0.408381</td>
#       <td>0.130435</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.441419</td>
#       <td>0.553184</td>
#       <td>0.141304</td>
#       <td>0.858696</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.431724</td>
#       <td>0.170946</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.353131</td>
#       <td>0.111873</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, max_lr=3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.148895</td>
#       <td>0.159621</td>
#       <td>0.054348</td>
#       <td>0.945652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.130657</td>
#       <td>0.235158</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.100581</td>
#       <td>0.203829</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.105117</td>
#       <td>0.189930</td>
#       <td>0.086957</td>
#       <td>0.913043</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.195114</td>
#       <td>0.254945</td>
#       <td>0.065217</td>
#       <td>0.934783</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.126804</td>
#       <td>1.021023</td>
#       <td>0.250000</td>
#       <td>0.750000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.100670</td>
#       <td>0.548404</td>
#       <td>0.163043</td>
#       <td>0.836957</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.145510</td>
#       <td>0.336369</td>
#       <td>0.097826</td>
#       <td>0.902174</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.138790</td>
#       <td>0.213952</td>
#       <td>0.065217</td>
#       <td>0.934783</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.109925</td>
#       <td>0.109139</td>
#       <td>0.043478</td>
#       <td>0.956522</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.097431</td>
#       <td>0.203656</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.077462</td>
#       <td>0.184503</td>
#       <td>0.076087</td>
#       <td>0.923913</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125051</td>
#       <td>0.190268</td>
#       <td>0.054348</td>
#       <td>0.945652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.071985</td>
#       <td>0.223603</td>
#       <td>0.054348</td>
#       <td>0.945652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.065651</td>
#       <td>0.164532</td>
#       <td>0.054348</td>
#       <td>0.945652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.051849</td>
#       <td>0.143870</td>
#       <td>0.021739</td>
#       <td>0.978261</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.rcParams.update({'font.size': 18})

val_preds,val_targets = learn.get_preds() 
y_test = pd.Series(np.array(val_preds.max(1)[1])).map(dict(zip([0,1,2],learn.data.classes)))
y_true = pd.Series(np.array(val_targets)).map(dict(zip([0,1,2],learn.data.classes)))
pd.DataFrame({'multiclass_roc_auc_score': multiclass_roc_auc_score(y_test, y_true)}, index = ['metrics'])
# Out:
#          multiclass_roc_auc_score
# metrics                  0.983696

# %%
interp = ClassificationInterpretation.from_learner(learn)

interp.most_confused(min_val=1)
# Out:
# [('VARIANT_LYMPHOCYTE', 'ATYPICAL_LYMPHOCYTE', 1),
#  ('VARIANT_LYMPHOCYTE', 'BLAST', 1)]

# %% [markdown]
# `Matriz de confusión` tras el fine tuning en Can Ruti

# %%
interp.plot_confusion_matrix(figsize=(7,7), dpi=110)

# %% [markdown]
# `Matriz de confusión Normalizada` tras el fine tuning en Can Ruti

# %%
interp.plot_confusion_matrix(figsize=(7,7), dpi=110, normalize=True)

# %%
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(35, 35))
